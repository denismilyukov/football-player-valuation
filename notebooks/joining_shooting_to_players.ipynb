# %%
import pandas as pd

pd.options.display.max_columns = 37
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

# %%
changes_final = {
    'é':'e',
    'ç':'c',
    'Ї':'I',
    'ć':'c',
    'ě':'e',
    'á':'a',
    'ä':'a',
    'ñ':'n',
    'ô':'o',
    'Ž':'Z',
    'ë':'e',
    'ã':'a',
    'ł':'l',
    'ś':'s',
    'Ó':'O',
    'š':'s',
    'Đ':'Dj',
    'ü':'u',
    'Á':'A',
    'ú':'u',
    'â':'a',
    'É':'E',
    'ê':'e',
    'í':'i',
    'ö':'o',
    'č':'c',
    'Ñ':'N',
    'Ö':'O',
    'ø':'o',
    'Ü':'U',
    'ę':'e',
    'ğ':'g',
    'ı':'i',
    'Þ':'Th',
    'è':'e',
    'ð':'d',
    'ý':'y',
    'Š':'S',
    'Ć':'C',
    'ž':'z',
    'ş':'s',
    'đ':'dj',
    'ò':'o',
    'ș':'s',
    'ă':'a',
    'Ç':'C',
    'Č':'C',
    'æ':'ae',
    'ń':'n',
    'ă':'a',
    'ț':'t',
    'Ł':'L',
    'ì':'i',
    'Ż':'Z',
    'ź':'z',
    'ō':'o',
    'ß':'ss',
    'ř':'r',
    'å':'a',
    'À':'A',
    'Ú':'U',
    'ů':'u',
    'õ':'o',
    'ū':'u',
    'ó':'o',
    'ï':'i',
    '\xad':''
}

changes = {
    'Г©':'é',
    'Г§':'ç',
    'ГЇ':'i',
    'Д‡':'ć',
    'Гі':'o',
    'Д›':'ě',
    'ГЎ':'á',
    'Г¤':'ä',
    'Г±':'ñ',
    'Гґ':'ô',
    'ЕЅ':'Ž',
    'Г«':'ë',
    'ГЈ':'ã',
    'Е‚':'ł',
    'Е›':'ś',
    'Г“':'Ó',
    'ЕЎ':'š',
    'Дђ':'Đ',
    'ГЃ':'Á',
    'Гє':'ú',
    'Гў':'â',
    'Г‰':'É',
    'ГЄ':'ê',
    'Гј':'ü',
    'Г¶':'ö',
    'ДЌ':'č',
    'Г‘':'Ñ',
    'Г–':'Ö',
    'Гё':'ø',
    'Гњ':'Ü',
    'Д™':'ę',
    'Дџ':'ğ',
    'Д±':'ı',
    'Гћ':'Þ',
    'ГЁ':'è',
    'Г°':'ð',
    'ГЅ':'ý',
    'Е ':'Š',
    'Д†':'Ć',
    'Еѕ':'ž',
    'Еџ':'ş',
    'Д‘':'đ',
    'ГІ':'ò',
    'Дѓ':'ă',
    'И™':'ș',
    'Г‡':'Ç',
    'ДЊ':'Č',
    'Г¦':'æ',
    'Е„':'ń',
    'Дѓ':'ă',
    'И›':'ț',
    'ЕЃ':'Ł',
    'Г¬':'ì',
    'Е»':'Ż',
    'Еє':'ź',
    'ЕЌ':'ō',
    'Гџ':'ß',
    'Е™':'ř',
    'ГҐ':'å',
    'Гљ':'Ú',
    'ГЂ':'À',
    'ЕЇ':'ů',
    'вЂ™':'’',
    'Гµ':'õ',
    'Е«':'ū',
    'Г‚':'Â',
    

    #'Г':'í'
}

champ_ids = ['BE1', 'BRA1', 'ES1', 'FR1', 'GB1', 'IT1', 'L1', 'NL1', 'PO1', 'RU1']

# %%
stats = pd.read_csv('../data/raw/stats/PO1_players_24-25.csv')
shooting = pd.read_csv('../data/raw/stats/PO1_misc_24-25.csv')

# %%
for i in range(len(stats)):
    if stats.at[i, 'Age'] != shooting.at[i, 'Age']:
        print(stats.loc[i])

# %%
stats.loc[45:50]
# Out:
#                     Player Nation    Pos        Squad   Age  MP  Starts   Min  \
# 45            Jan Bednarek    POL     DF  Southampton  28.0  30      30  2531
# 46     Armel Bella Kotchap    GER     DF  Southampton  22.0   4       2   331
# 47  Jean-Ricner Bellegarde    FRA  MF,FW       Wolves  26.0  35      20  1677
# 48       Rodrigo Bentancur    URU     MF    Tottenham  27.0  26      21  1645
# 49          Daniel Bentley    ENG     GK       Wolves  31.0   2       2   180
# 50            Sander Berge    NOR     MF       Fulham  26.0  31      26  2224
#
#      90s  Gls  Ast  G+A  G-PK  PK  PKatt  CrdY  CrdR   xG  ...  npxG.1  \
# 45  28.1    2    0    2     2   0      0     7     0  0.7  ...    0.02
# 46   3.7    0    0    0     0   0      0     0     0  0.3  ...    0.09
# 47  18.6    2    7    9     2   0      0     3     0  1.5  ...    0.08
# 48  18.3    2    0    2     2   0      0     9     0  1.3  ...    0.07
# ...

# %%
shooting.loc[45:50]
# Out:
#                     Player Nation Pos              Squad   Age   90s  CrdY  \
# 45        Altay BayД±ndД±r    TUR  GK     Manchester Utd  26.0   4.0     0
# 46            Jan Bednarek    POL  DF        Southampton  28.0  28.1     7
# 47     Armel Bella Kotchap    GER  DF        Southampton  22.0   3.7     0
# 48  Jean-Ricner Bellegarde    HAI  MF             Wolves  26.0  18.6     3
# 49       Rodrigo Bentancur    URU  MF  Tottenham Hotspur  27.0  18.3     9
# 50          Daniel Bentley    ENG  GK             Wolves  31.0   2.0     0
#
#     CrdR  2CrdY  Fls  Fld  Off  Crs  Int  TklW  PKwon  PKcon  OG
# 45     0      0    0    1    0    0    0     0    NaN    NaN   0
# 46     0      0   31   13    0    1   55    19    NaN    NaN   0
# 47     0      0    3    2    0    0    5     5    NaN    NaN   0
# 48     0      0   31   46    1   42    8    23    NaN    NaN   0
# 49     0      0   34   10    1    4   38    22    NaN    NaN   0
# ...

# %%
for letter in changes:
    shooting['Player'] = shooting['Player'].str.replace(letter, changes[letter])
for letter in changes_final:
    shooting['Player'] = shooting['Player'].str.replace(letter, changes_final[letter])
shooting.loc[45:50]
# Out:
#                     Player Nation Pos              Squad   Age   90s  CrdY  \
# 45          Altay Bayindir    TUR  GK     Manchester Utd  26.0   4.0     0
# 46            Jan Bednarek    POL  DF        Southampton  28.0  28.1     7
# 47     Armel Bella Kotchap    GER  DF        Southampton  22.0   3.7     0
# 48  Jean-Ricner Bellegarde    HAI  MF             Wolves  26.0  18.6     3
# 49       Rodrigo Bentancur    URU  MF  Tottenham Hotspur  27.0  18.3     9
# 50          Daniel Bentley    ENG  GK             Wolves  31.0   2.0     0
#
#     CrdR  2CrdY  Fls  Fld  Off  Crs  Int  TklW  PKwon  PKcon  OG
# 45     0      0    0    1    0    0    0     0    NaN    NaN   0
# 46     0      0   31   13    0    1   55    19    NaN    NaN   0
# 47     0      0    3    2    0    0    5     5    NaN    NaN   0
# 48     0      0   31   46    1   42    8    23    NaN    NaN   0
# 49     0      0   34   10    1    4   38    22    NaN    NaN   0
# ...

# %%
for letter in changes_final:
    stats['Player'] = stats['Player'].str.replace(letter, changes_final[letter])

# %%
df = stats.drop(['2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'Int', 'TklW', 'OG'], axis=1).merge(shooting[['Player', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'Int', 'TklW', 'OG']], how='left', on='Player')

# %%
df[df['2CrdY'].isna()]
# Out:
#                       Player Nation    Pos            Squad   Age  MP  Starts  \
# 39         Benoît Badiashile    FRA     DF          Chelsea  23.0   5       3
# 103          Vladimir Coufal    CZE     DF         West Ham  31.0  22      11
# 125                Luis Diaz    COL     FW        Liverpool  27.0  36      28
# 134        Nicolas Dominguez    ARG  MF,FW  Nott'ham Forest  26.0  34      23
# 179            Andres Garcia    ESP  DF,MF      Aston Villa  21.0   7       5
# 205           İlkay Gundogan    GER     MF  Manchester City  33.0  33      25
# 261        Caoimhin Kelleher    IRL     GK        Liverpool  25.0  10      10
# 269           Antonin Kinsky    CZE     GK        Tottenham  21.0   6       6
# 313        Emiliano Martinez    ARG     GK      Aston Villa  31.0  37      37
# 314        Lisandro Martinez    ARG     DF   Manchester Utd  26.0  20      20
# 398  Hakon Rafn Valdimarsson    ISL     GK        Brentford  22.0   2       1
# ...

# %%
shooting[shooting['Player'].str.contains('degaa')]
# Out:
#               Player Nation Pos    Squad   Age   90s  CrdY  CrdR  2CrdY  Fls  \
# 561  Martin Гdegaard    NOR  MF  Arsenal  25.0  25.8     4     0      0   12
#
#      Fld  Off  Crs  Int  TklW  PKwon  PKcon  OG
# 561   23    1   86    6     8    NaN    NaN   0

# %%
df.iloc[539, 42:] = [0, 12, 23, 1, 86, 6, 8, 0]
df.iloc[539]
# Out:
# Player        Martin Ødegaard
# Nation                    NOR
# Pos                        MF
# Squad                 Arsenal
# Age                      25.0
# MP                         30
# Starts                     26
# Min                      2325
# 90s                      25.8
# Gls                         3
# Ast                         8
# G+A                        11
# G-PK                        2
# PK                          1
# PKatt                       1
# CrdY                        4
# CrdR                        0
# xG                        4.8
# npxG                      4.0
# xAG                       5.4
# npxG+xAG                  9.5
# PrgC                       92
# PrgP                      258
# PrgR                      154
# Gls.1                    0.12
# Ast.1                    0.31
# G+A.1                    0.43
# G-PK.1                   0.08
# G+A-PK                   0.39
# xG.1                     0.19
# xAG.1                    0.21
# ...

# %%
df.to_csv('../data/raw/stats/GB1_players_24-25.csv', index=False)

# %%
df.columns[42]
# Out:
# '2CrdY'
